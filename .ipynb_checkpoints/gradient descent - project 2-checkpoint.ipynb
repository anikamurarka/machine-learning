# %%
def cost(m, data):
    M = data.shape[0]
#     X = data[]
    num_feat = data.shape[1]-1
    cst=0
    for i in range(M):
        cst+=(1/M)*((data[i][num_feat]-sum(m*data[:,:num_feat][i]))**2)
    print("cost",cst)

# %%
def step(data,L_R,m):
    M = data.shape[0]
#     print("M",M)
    num_feat = data.shape[1]-1
#     print("num_feat",num_feat)
    slope_m = np.zeros((data.shape[1]-1,),int)
    for k in range(num_feat):
        for i in range(M):
            y = data[i][num_feat]
#             print("y",y)
            inner_calc = 0
            for j in range(num_feat):
                x = data[i][j]
#                 print("x",x)
                inner_calc += m[j]*x
#             print(y,inner_calc,data[i][k],M)
            slope_m[k] += -((y - inner_calc)*data[i][k]*2)/M
#             print("slope",slope_m)
    new_m = m - L_R*slope_m
    cost(m,data)
    return new_m

# %%
def gd2(data,L_R,no_of_iterations):
    m = np.zeros((data.shape[1]-1,),int)
#     print(data.shape)
#     print(m.shape)
    iterations = no_of_iterations
    while no_of_iterations>0:
        m = step(data,L_R,m)
        no_of_iterations -= 1
    return m

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
def run() :
    data_train = np.loadtxt("gd2_training_ccpp_x_y_train.csv",delimiter=',')
    data_test = np.loadtxt("gd2_test_ccpp_x_test.csv",delimiter=',')
    print(data_train)
    print(data_test.shape)
#     print(pd.DataFrame(data_train))
    x_test = data_test
    b = np.ones((data_test.shape[0],1),dtype = int)
#     print(b)
#     print(x_test.shape)
    x_test = np.append(x_test,b,axis=1)
    b = np.ones((data_train.shape[0],),dtype = int)
    data_train = np.insert(data_train,data_train.shape[1]-1,b,axis=1)
#     print(x_test.shape)
    L_R = 0.000001
    no_of_iterations = 1000
    m = gd2(data_train,L_R,no_of_iterations)
    print(m.shape)
    ypred = x_test.dot(m)
    np.set_printoptions(formatter={'float_kind':'{:f}'.format})
#     print(ypred.shape)
    print(ypred)
    np.savetxt('yPred_gd_2.csv',ypred)

# %%
run()
# Out:
# [[8.580000 38.380000 1021.030000 84.370000 482.260000]
#  [21.790000 58.200000 1017.210000 66.740000 446.940000]
#  [16.640000 48.920000 1011.550000 78.760000 452.560000]
#  ...
#  [29.800000 69.340000 1009.360000 64.740000 437.650000]
#  [16.370000 54.300000 1017.940000 63.630000 459.970000]
#  [30.110000 62.040000 1010.690000 47.960000 444.420000]]
# (2392, 4)
# cost 206801.35285512806
# cost 130411.46656486086
# cost 82325.72804552891
# cost 52043.85999811868
# cost 32967.08808733401
# cost 20940.679476816775
# cost 13356.051943410119
# cost 8569.454934810863
# cost 5542.419340441881
# cost 3627.282747789533
# cost 2414.9968933346777
# cost 1644.5804556577011
# cost 1153.2976223069281
# cost 839.335514753842
# cost 637.968556574522
# cost 508.4689104868816
# cost 424.5921185854808
# cost 369.8408708947283
# cost 334.00083429840004
# cost 257.08735427882743
# cost 257.0863319330985
# cost 257.08530991592664
# cost 257.08428822731014
# cost 257.08326686725104
# cost 257.0822458357453
# cost 257.0812251327984
# cost 257.08020475840607
# cost 257.0791847125699
# cost 257.0781649952896
# cost 257.0771456065663
# cost 257.076126546397
# cost 257.07536246688676
# cost 257.0745985721873
# cost 257.07383486230214
# cost 257.07307133722924
# cost 257.07230799696964
# cost 257.0715448415219
# cost 257.0707818708866
# cost 257.0700190850658
# cost 257.06925648405513
# cost 257.06849406786057
# cost 257.06773183647596
# cost 257.0669697899059
# cost 257.06620792814726
# cost 257.0654462512025
# cost 257.06493856924635
# cost 257.06443096942826
# cost 257.06392345175
# cost 257.0634160162102
# cost 257.0629086628098
# cost 257.06240139154886
# cost 257.0618942024267
# cost 257.06138709544246
# cost 257.06088007059964
# cost 257.06037312789266
# cost 257.0598662673262
# cost 257.05935948889874
# cost 257.0588527926104
# cost 257.0583461784618
# cost 257.0578396464514
# cost 257.0573331965796
# cost 257.0568268288467
# cost 257.05632054325355
# cost 257.0560674312588
# cost 257.05581433979927
# cost 257.0555612688752
# cost 257.0553082184833
# cost 257.05505518862844
# cost 257.0548021793065
# cost 257.05454919052124
# cost 257.0542962222708
# cost 257.0540432745536
# cost 257.0537903473715
# cost 257.0535374407243
# cost 257.05328455461216
# cost 257.05303168903583
# cost 257.052778843992
# cost 257.0525260194835
# cost 257.0522732155113
# cost 257.0520204320729
# cost 257.0517676691694
# cost 257.05151492679965
# cost 257.0512622049646
# cost 257.0510095036663
# cost 257.05075682290067
# cost 257.0505041626709
# cost 257.05025152297543
# cost 257.04999890381504
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/x_/2nhckcv12_94jtlx8yl6x16m0000gn/T/ipykernel_10684/766504495.py in <module>
# ----> 1 run()
#
# /var/folders/x_/2nhckcv12_94jtlx8yl6x16m0000gn/T/ipykernel_10684/3794433553.py in run()
#      18     L_R = 0.0000001
#      19     no_of_iterations = 1000
# ---> 20     m = gd2(data_train,L_R,no_of_iterations)
#      21     print(m.shape)
#      22     ypred = x_test.dot(m)
#
# /var/folders/x_/2nhckcv12_94jtlx8yl6x16m0000gn/T/ipykernel_10684/2584665469.py in gd2(data, L_R, no_of_iterations)
#       5     iterations = no_of_iterations
#       6     while no_of_iterations>0:
# ----> 7         m = step(data,L_R,m)
#       8         no_of_iterations -= 1
#       9     return m
#
# /var/folders/x_/2nhckcv12_94jtlx8yl6x16m0000gn/T/ipykernel_10684/1644766867.py in step(data, L_R, m)
#      15                 inner_calc += m[j]*x
#      16 #             print(y,inner_calc,data[i][k],M)
# ---> 17             slope_m[k] += -((y - inner_calc)*data[i][k]*2)/M
#      18 #             print("slope",slope_m)
#      19     new_m = m - L_R*slope_m
#
# KeyboardInterrupt:
